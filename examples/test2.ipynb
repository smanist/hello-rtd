# %% [markdown]
# # Some title - Test 2

# %% [markdown]
# Some text
#
# Some math
#
# $$
# \dot{x} = f(x,u)
# $$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1, 1, 51)
y = x**2

f = plt.figure()
plt.plot(x, np.cos(y))

# %% [markdown]
# Some more text
#
# Some more text
#
# Some more text
#
# Some more text

# %%
f = plt.figure()
plt.plot(x, np.sin(y))
