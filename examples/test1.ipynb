# %% [markdown]
# # Some title

# %% [markdown]
# $$
# \newcommand\bN{\mathbb{N}}
# $$

# %% [markdown]
# Some text
#
# Some math
# $$
# \dot{x} = f(x,u)
# $$
#
# And inline: $\partial x/\partial y$.

# %% [markdown]
# \begin{gather*}
# a_1=b_1+c_1\\
# a_2=b_2+c_2-d_2+e_2
# \end{gather*}

# %% [markdown]
# $\bN$

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-1, 1, 51)
y = x**2

f = plt.figure()
plt.plot(x, y)

# %% [markdown]
# Some more text
#
# Some more text
#
# Some more text
#
# Some more text

# %%
f = plt.figure()
plt.plot(x, -y)
